# %%
# Cell for loading environment variables from config.py,
# which is located one directory above this notebook.
import sys
import os

current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, ".."))
sys.path.insert(0, parent_dir)

from config import set_environment

set_environment()

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=1.0)

# %% [markdown]
# # Streaming

# %% [markdown]
# Firts, let's download a public MMLU [dataset](https://huggingface.co/datasets/cais/mmlu) from HuggingFace:

# %%
from datasets import load_dataset
ds = load_dataset("cais/mmlu", "high_school_geography")
# Out:
# README.md:   0%|          | 0.00/53.2k [00:00<?, ?B/s]
# dataset_infos.json:   0%|          | 0.00/138k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/28.2k [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/6.16k [00:00<?, ?B/s]
# dev-00000-of-00001.parquet:   0%|          | 0.00/3.93k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/198 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/22 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/5 [00:00<?, ? examples/s]

# %% [markdown]
# Now, let's create a simple research agent:

# %%
from langchain_community.agent_toolkits.load_tools import load_tools
from langchain.agents import create_agent


research_tools = load_tools(
  tool_names=["ddg-search", "arxiv", "wikipedia"],
  llm=llm
)

system_prompt = (
    "You're a hard-working, curious and creative student. "
    "You're working on exam quesion. Think step by step."
    "Always provide an argumentation for your answer. "
    "Do not assume anything, use available tools to search "
    "for evidence and supporting statements."
)

# %%
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate
from langgraph.graph import MessagesState
from langchain.agents import AgentState

raw_prompt_template = (
    "Answer the following multiple-choice question. "
    "\nQUESTION:\n{question}\n\nANSWER OPTIONS:\n{options}\n"
)

class ResearchState(AgentState):
  question: str
  options: str

research_agent = create_agent(model=llm, tools=research_tools, state_schema=ResearchState, system_prompt=system_prompt)

# %% [markdown]
# Now we need to prepare a _question` and answer _options_:

# %%
from langchain_core.messages import HumanMessage


i = 6
ds_dict = ds["test"].take(100).to_dict()
question = ds_dict["question"][i]
options = "\n".join([f"{i}. {a}" for i, a in enumerate(ds_dict["choices"][i])])

formatted_prompt = raw_prompt_template.format(question=question, options=options)
user_input = HumanMessage(content=formatted_prompt)

initial_state = {
    "question": question,
    "options": options,
    "messages": [
        user_input
    ],
}

# %% [markdown]
# Compare outputs (and available amount of messages in the `event` instance) when using `stream_mode=values` vs `updates`:

# %%
async for _, event in research_agent.astream(initial_state, stream_mode=["values"]):
  print(len(event["messages"]))
# Out:
# 0
# WARNING:langchain_google_vertexai.chat_models:This model can reply with multiple function calls in one response. Please don't rely on `additional_kwargs.function_call` as only the last one will be saved.Use `tool_calls` instead.
# WARNING:langchain_google_vertexai.chat_models:This model can reply with multiple function calls in one response. Please don't rely on `additional_kwargs.function_call` as only the last one will be saved.Use `tool_calls` instead.
# WARNING:langchain_google_vertexai.chat_models:This model can reply with multiple function calls in one response. Please don't rely on `additional_kwargs.function_call` as only the last one will be saved.Use `tool_calls` instead.
# 1
# 5
# 6

# %%
async for _, event in research_agent.astream(initial_state, stream_mode=["updates"]):
  node = list(event.keys())[0]
  print(node, len(event[node].get("messages", [])))
# Out:
# agent 1
# tools 1
# agent 1

# %%
async for _, event in research_agent.astream(initial_state, stream_mode=["updates"]):
  print(event)
# Out:
# WARNING:langchain_google_vertexai.chat_models:This model can reply with multiple function calls in one response. Please don't rely on `additional_kwargs.function_call` as only the last one will be saved.Use `tool_calls` instead.
# WARNING:langchain_google_vertexai.chat_models:This model can reply with multiple function calls in one response. Please don't rely on `additional_kwargs.function_call` as only the last one will be saved.Use `tool_calls` instead.
# WARNING:langchain_google_vertexai.chat_models:This model can reply with multiple function calls in one response. Please don't rely on `additional_kwargs.function_call` as only the last one will be saved.Use `tool_calls` instead.
# {'agent': {'messages': [AIMessage(content='A relict boundary is a former boundary line that no longer functions as an international border but is still visible in the cultural landscape. To determine which country does NOT have a well-known example of a relict boundary, I will investigate each option.\n\n*   **Vietnam:** I\'ll search for "relict boundary Vietnam" to see if there are any well-known examples.\n*   **United Kingdom:** I\'ll search for "relict boundary United Kingdom".\n*   **Germany:** I\'ll search for "relict boundary Germany".\n*   **Bolivia:** I\'ll search for "relict boundary Bolivia".\n\n', additional_kwargs={'function_call': {'name': 'duckduckgo_search', 'arguments': '{"query": "relict boundary Bolivia"}'}}, response_metadata={'is_blocked': False, 'safety_ratings': [], 'usage_metadata': {'prompt_token_count': 249, 'candidates_token_count': 173, 'total_token_count': 422, 'prompt_tokens_details': [{'modality': 1, 'token_count': 249}], 'candidates_tokens_details': [{'modality': 1, 'token_count': 173}], 'cached_content_token_count': 0, 'cache_tokens_details': []}, 'finish_reason': 'STOP', 'avg_logprobs': -0.027671648587794664, 'model_name': 'gemini-2.0-flash-001'}, id='run-e441d0b0-2974-46b6-a1c0-4500317b1902-0', tool_calls=[{'name': 'duckduckgo_search', 'args': {'query': 'relict boundary Vietnam'}, 'id': '05f60b03-1869-47b4-8221-6c5bf19ccbfc', 'type': 'tool_call'}, {'name': 'duckduckgo_search', 'args': {'query': 'relict boundary United Kingdom'}, 'id': '545b52a9-e6af-4873-a752-311281d3a776', 'type': 'tool_call'}, {'name': 'duckduckgo_search', 'args': {'query': 'relict boundary Germany'}, 'id': '40898393-9274-4092-b06f-7bbb169831cc', 'type': 'tool_call'}, {'name': 'duckduckgo_search', 'args': {'query': 'relict boundary Bolivia'}, 'id': '68cdad50-7821-4be8-abd7-7b915ddc017c', 'type': 'tool_call'}], usage_metadata={'input_tokens': 249, 'output_tokens': 173, 'total_tokens': 422})]}}
# {'tools': {'messages': [ToolMessage(content='Correct, the border between North and South Vietnam is a relic boundary. However other correct answers/good examples can be the Great Wall of China, the Mason and Dixon Line (border between the Union and Confederates), Hadrain\'s Wall, and the border between North and South Yemen. ... "Relict boundary: A boundary that no longer exists, although ... Essay Example: Relic boundaries, a term steeped in the study of geography and history, are fascinating remnants of the past that continue to influence present-day landscapes and societies. These are not mere lines on a map but are storied demarcations that have survived changes in political What is a geometric boundary? A geometric boundary is a border that is established using lines of latitude and longitude. These boundaries are straight and often disregard physical features or cultural landscapes. The border between the United States and Canada along the 49th parallel is a prime example of a geometric boundary. Relic boundary. A relic boundary is a former boundary that no longer exists but still holds significance, usually economic or cultural. An example of a relic boundary is the Berlin Wall, which divided East and West Germany before reunification. Superimposed boundary. A superimposed boundary is a boundary drawn by outside power without attention to existing borders or social, cultural, or ... Study with Quizlet and memorize flashcards containing terms like Boundary, Frontier, Boundary Delimitation and more. ... Vietnam-China border, Ireland-Northern Ireland border, Demilitarized Zone. aka DMZ, zone from which military forces or operations or installations are prohibited; ... Relict Boundary.', name='duckduckgo_search', id='cbe78a27-c529-45e6-b884-5125258a1935', tool_call_id='05f60b03-1869-47b4-8221-6c5bf19ccbfc'), ToolMessage(content='It is physically separate from the rest of the United Kingdom, a multinational state. E. It is a stateless nation, as the entire island of Ireland is under the control of the United Kingdom. ... Geographers would say that where the wall once stood now acts as a: A. superimposed boundary B. relict boundary C. fortified boundary D. antecedent ... Study with Quizlet and memorize flashcards containing terms like consequent boundaries, geometric boundary, relict boundary and more. ... the transfer of powers and responsibilities from the federal government to the states ex United kingdom to Ireland. Culture cohesion. Cultural unity; occurs when the members of a society are culturally united. Example: The border between the United States and Canada along the Rocky Mountains serves as an excellent example of an antecedent boundary. This vast mountain range was a pre-existing geographical feature before significant populations or states were formed on either side of it. ... Relict Boundaries. Relict boundaries are borders that no ... United Kingdom of Great Britain and Northern Ireland. Site number: 2555. Area: 6,377.6 ha. Designation date: ... or concerning the delimitation of its frontiers or boundaries. ... and contains relict areas of saltmarsh, extensive grazing marshes and reedbeds. Dungeness, Romney Marsh and Rye Bay is important for breeding, wintering and passage ... Relic boundaries, a term steeped in the study of geography and history, are fascinating remnants of the past that continue to influence present-day landscapes and societies. These are not mere lines on a map but are storied demarcations that have survived changes in political regimes, cultural shifts, and even the relentless march of ...', name='duckduckgo_search', id='9fa3f7b6-2843-4b72-8281-a7c013711889', tool_call_id='545b52a9-e6af-4873-a752-311281d3a776'), ToolMessage(content='The inner German border (German: innerdeutsche Grenze or deutsch-deutsche Grenze; initially also Zonengrenze) was the frontier between the German Democratic Republic (GDR, East Germany) and the Federal Republic of Germany (FRG, West Germany) from 1949 to 1990. ...
# {'agent': {'messages': [AIMessage(content="Based on the search results:\n\n*   **Vietnam:** The border between North and South Vietnam is a relict boundary.\n*   **United Kingdom:** Mentions of relict boundaries in relation to the UK exist, though less prominent than the Germany example.\n*   **Germany:** The inner German border between East and West Germany is a well-known example of a relict boundary.\n*   **Bolivia:** While Bolivia has lost territory and is landlocked, the search results don't point to a specific, well-known example of a *relict boundary* within the country itself. The information focuses more on border disputes and loss of access to the sea.\n\nTherefore, the country that does NOT have a well-known example of a relict boundary among the options is Bolivia.\n\nANSWER: 3\n", additional_kwargs={}, response_metadata={'is_blocked': False, 'safety_ratings': [], 'usage_metadata': {'prompt_token_count': 1818, 'candidates_token_count': 168, 'total_token_count': 1986, 'prompt_tokens_details': [{'modality': 1, 'token_count': 1818}], 'candidates_tokens_details': [{'modality': 1, 'token_count': 168}], 'cached_content_token_count': 0, 'cache_tokens_details': []}, 'finish_reason': 'STOP', 'avg_logprobs': -0.18278472764151438, 'model_name': 'gemini-2.0-flash-001'}, id='run-8c33b1ce-ce9a-4f5a-900d-292340a63a32-0', usage_metadata={'input_tokens': 1818, 'output_tokens': 168, 'total_tokens': 1986})]}}

# %% [markdown]
# We can also explore what types of events we have seen:

# %%
seen_events = set([])
async for event in research_agent.astream_events(initial_state, version="v1"):
  if event["event"] not in seen_events:
    seen_events.add(event["event"])

print(seen_events)
# Out:
# WARNING:langchain_google_vertexai.chat_models:This model can reply with multiple function calls in one response. Please don't rely on `additional_kwargs.function_call` as only the last one will be saved.Use `tool_calls` instead.
# WARNING:langchain_google_vertexai.chat_models:This model can reply with multiple function calls in one response. Please don't rely on `additional_kwargs.function_call` as only the last one will be saved.Use `tool_calls` instead.
# WARNING:langchain_google_vertexai.chat_models:This model can reply with multiple function calls in one response. Please don't rely on `additional_kwargs.function_call` as only the last one will be saved.Use `tool_calls` instead.
# {'on_chat_model_stream', 'on_chat_model_end', 'on_tool_start', 'on_chain_end', 'on_chain_stream', 'on_tool_end', 'on_chain_start', 'on_chat_model_start', 'on_prompt_start', 'on_prompt_end'}
